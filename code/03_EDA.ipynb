# %% [markdown]
# ### import libs

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import os
import re
import warnings
import pickle

# %%
warnings.filterwarnings(action="ignore")
pd.options.display.max_columns = None

# %% [markdown]
# ### read data

# %%
def readCsvFile(filepath):
    """
        Function to read csv file
        args:
            filepath : path to csv file
        return:
            df : dataframe
    """
    
    df = pd.read_csv(filepath)
    df.columns = df.columns.str.lower().str.replace(" ", "_")
    
    df.drop(df.columns[-1], inplace=True, axis = 1)
    
    return df

# %%
raw_aid_df = readCsvFile('../data/API_DT.ODA.ALLD.CD_DS2_en_csv_v2_5362759.csv')

# %%
raw_aid_df.head(2)
# Out:
#                   country_name country_code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
#
#                                       indicator_name  indicator_code  1960  \
# 0  Net official development assistance and offici...  DT.ODA.ALLD.CD   NaN
# 1  Net official development assistance and offici...  DT.ODA.ALLD.CD   NaN
#
#    1961  1962  1963  1964  1965  1966  1967  1968  1969          1970  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN           NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  4.915300e+08
#
#            1971          1972          1973          1974          1975  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1  5.639600e+08  6.889900e+08  8.048100e+08  1.265530e+09  1.871240e+09
#
#            1976          1977          1978          1979          1980  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1  1.689510e+09  2.117160e+09  2.778050e+09  3.852600e+09  4.669250e+09
#
#            1981          1982          1983          1984          1985  \
# 0           NaN           NaN           NaN           NaN  1.204000e+07
# 1  4.549970e+09  4.830960e+09  4.704880e+09  4.588420e+09  5.459230e+09
#
#            1986          1987          1988          1989          1990  \
# 0  4.043000e+07  2.091000e+07  1.929000e+07  2.433000e+07  2.998000e+07
# 1  6.289620e+09  7.560670e+09  8.521050e+09  8.447230e+09  1.048072e+10
#
#            1991          1992          1993          1994          1995  \
# 0  2.497000e+07  2.998000e+07  2.486000e+07  1.826000e+07  2.580000e+07
# 1  1.019461e+10  1.141019e+10  1.029058e+10  1.031032e+10  1.080096e+10
#
#            1996          1997          1998          1999          2000  \
# 0  1.953000e+07  2.507000e+07  1.126000e+07 -7.380000e+06  1.150000e+07
# 1  8.218980e+09  8.028640e+09  7.679370e+09  7.481400e+09  7.995110e+09
#
#            2001          2002          2003          2004          2005  \
# 0 -1.700000e+06  1.049000e+07  7.622000e+07 -1.132000e+07           NaN
# 1  8.510100e+09  1.140720e+10  1.652204e+10  1.624948e+10  1.641143e+10
#
#            2006          2007          2008          2009          2010  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1  1.845283e+10  2.048603e+10  2.367998e+10  2.514313e+10  2.497745e+10
#
#            2011          2012          2013          2014          2015  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1  2.853379e+10  2.622688e+10  2.920757e+10  2.590026e+10  2.549711e+10
#
#            2016          2017          2018          2019  2020  2021
# 0           NaN           NaN           NaN           NaN   NaN   NaN
# 1  2.506915e+10  2.788161e+10  2.752549e+10  3.020291e+10   NaN   NaN

# %%
raw_infltn_df = readCsvFile("../data/API_FP.CPI.TOTL.ZG_DS2_en_csv_v2_5358428.csv")

# %%
raw_infltn_df.head(2)
# Out:
#                   country_name country_code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
#
#                           indicator_name  indicator_code  1960  1961  1962  \
# 0  Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG   NaN   NaN   NaN
# 1  Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG   NaN   NaN   NaN
#
#    1963  1964  1965  1966  1967  1968  1969  1970  1971  1972  1973  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#         1974       1975       1976       1977       1978      1979       1980  \
# 0        NaN        NaN        NaN        NaN        NaN       NaN        NaN
# 1  19.598394  15.224099  11.216471  14.238055  12.526893  15.06985  15.066512
#
#         1981       1982       1983       1984       1985       1986  \
# 0        NaN        NaN        NaN        NaN   4.032258   1.073966
# 1  14.461591  12.139918  11.567524  10.983863  13.006566  13.891972
#
#         1987       1988       1989       1990       1991       1992  \
# 0   3.643045   3.121868   3.991628   5.836688   5.555556   3.873375
# 1  12.563443  12.522254  12.558202  12.457914  17.678100  16.167612
#
#         1993       1994       1995      1996       1997      1998      1999  \
# 0   5.215560   6.311080   3.361391  3.225288   2.999948  1.869489  2.280372
# 1  13.135661  14.852815  12.288591  9.706586  10.249599  7.495256  7.819865
#
#        2000      2001      2002      2003      2004      2005      2006  \
# 0  4.044021  2.883604  3.315247  3.656365  2.529129  3.397787  3.608024
# 1  8.601485  5.840354  8.763754  7.449700  5.023421  8.558038  8.898164
#
#        2007       2008      2009      2010      2011      2012      2013  \
# 0  5.392568   8.955987 -2.135429  2.078141  4.316297  0.627472 -2.372065
# 1  8.450775  12.566645  8.954218  5.537538  8.971206  9.158707  5.750981
#
#        2014      2015      2016      2017      2018      2019      2020  \
# 0  0.421441  0.474764 -0.931196 -1.028282  3.626041  4.257462       NaN
# 1  5.370290  5.250171  6.571396  6.399343  4.720811  4.120246  6.362961
#
#        2021
# 0       NaN
# 1  6.079328

# %%
raw_pvrty_df = readCsvFile("../data/API_SI.POV.DDAY_DS2_en_csv_v2_5358982.csv")

# %%
raw_pvrty_df.head(2)
# Out:
#                   country_name country_code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
#
#                                       indicator_name indicator_code  1960  \
# 0  Poverty headcount ratio at $2.15 a day (2017 P...    SI.POV.DDAY   NaN
# 1  Poverty headcount ratio at $2.15 a day (2017 P...    SI.POV.DDAY   NaN
#
#    1961  1962  1963  1964  1965  1966  1967  1968  1969  1970  1971  1972  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    1973  1974  1975  1976  1977  1978  1979  1980  1981  1982  1983  1984  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    1985  1986  1987  1988  1989  1990  1991  1992  1993  1994  1995  1996  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    1997  1998  1999  2000  2001  2002  2003  2004  2005  2006  2007  2008  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    2009  2010  2011  2012  2013  2014  2015  2016  2017  2018  2019  2020  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    2021
# 0   NaN
# 1   NaN

# %%
raw_unemplmnt_df = readCsvFile("../data/API_SL.UEM.TOTL.ZS_DS2_en_csv_v2_5358416.csv")

# %%
raw_unemplmnt_df.head(2)
# Out:
#                   country_name country_code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
#
#                                       indicator_name  indicator_code  1960  \
# 0  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS   NaN
# 1  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS   NaN
#
#    1961  1962  1963  1964  1965  1966  1967  1968  1969  1970  1971  1972  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    1973  1974  1975  1976  1977  1978  1979  1980  1981  1982  1983  1984  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    1985  1986  1987  1988  1989  1990      1991      1992      1993      1994  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN       NaN       NaN       NaN       NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN  7.333336  7.318747  7.242706  7.160694
#
#        1995      1996      1997      1998      1999      2000      2001  \
# 0       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1  7.063796  7.055998  7.090541  7.060097  7.015272  6.939536  6.850376
#
#        2002      2003      2004      2005      2006      2007      2008  \
# 0       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1  6.803537  6.741241  6.535173  6.373503  6.347598  6.283421  6.232561
#
#        2009      2010      2011      2012      2013      2014      2015  \
# 0       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1  6.295587  6.933645  6.715358  6.599356  6.512784  6.555645  6.707142
#
#        2016      2017      2018      2019      2020      2021
# 0       NaN       NaN       NaN       NaN       NaN       NaN
# 1  6.855589  6.940365  6.913046  7.121664  7.631303  7.920219

# %%
cntry_code_dtl = readCsvFile('../data/country_code_dtls.csv')

# %%
cntry_code_dtl.head(2)
# Out:
#   country_code                     region  incomegroup  \
# 0          ABW  Latin America & Caribbean  High income
# 1          AFE                        NaN          NaN
#
#                                         specialnotes  \
# 0                                                NaN
# 1  26 countries, stretching from the Red Sea in t...
#
#                      tablename
# 0                        Aruba
# 1  Africa Eastern and Southern

# %% [markdown]
# ### transform tables

# %%
raw_aid_df.dtypes
# Out:
# country_name       object
# country_code       object
# indicator_name     object
# indicator_code     object
# 1960              float64
#                    ...
# 2017              float64
# 2018              float64
# 2019              float64
# 2020              float64
# 2021              float64
# Length: 66, dtype: object

# %%
cntry_code_dtl.dtypes
# Out:
# country_code    object
# region          object
# incomegroup     object
# specialnotes    object
# tablename       object
# dtype: object

# %%
# join all tables with country_code

aid_df = raw_aid_df.merge(cntry_code_dtl, how = 'left', on = "country_code")
inflation_df = raw_infltn_df.merge(cntry_code_dtl, how = "left", on = "country_code")
povrty_df = raw_pvrty_df.merge(cntry_code_dtl, how = 'left', on = "country_code")
unemplmnt_df = raw_unemplmnt_df.merge(cntry_code_dtl, how = 'left', on = "country_code")

# %%
aid_df.head(2)
# Out:
#                   country_name country_code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
#
#                                       indicator_name  indicator_code  1960  \
# 0  Net official development assistance and offici...  DT.ODA.ALLD.CD   NaN
# 1  Net official development assistance and offici...  DT.ODA.ALLD.CD   NaN
#
#    1961  1962  1963  1964  1965  1966  1967  1968  1969          1970  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN           NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  4.915300e+08
#
#            1971          1972          1973          1974          1975  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1  5.639600e+08  6.889900e+08  8.048100e+08  1.265530e+09  1.871240e+09
#
#            1976          1977          1978          1979          1980  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1  1.689510e+09  2.117160e+09  2.778050e+09  3.852600e+09  4.669250e+09
#
#            1981          1982          1983          1984          1985  \
# 0           NaN           NaN           NaN           NaN  1.204000e+07
# 1  4.549970e+09  4.830960e+09  4.704880e+09  4.588420e+09  5.459230e+09
#
#            1986          1987          1988          1989          1990  \
# 0  4.043000e+07  2.091000e+07  1.929000e+07  2.433000e+07  2.998000e+07
# 1  6.289620e+09  7.560670e+09  8.521050e+09  8.447230e+09  1.048072e+10
#
#            1991          1992          1993          1994          1995  \
# 0  2.497000e+07  2.998000e+07  2.486000e+07  1.826000e+07  2.580000e+07
# 1  1.019461e+10  1.141019e+10  1.029058e+10  1.031032e+10  1.080096e+10
#
#            1996          1997          1998          1999          2000  \
# 0  1.953000e+07  2.507000e+07  1.126000e+07 -7.380000e+06  1.150000e+07
# 1  8.218980e+09  8.028640e+09  7.679370e+09  7.481400e+09  7.995110e+09
#
#            2001          2002          2003          2004          2005  \
# 0 -1.700000e+06  1.049000e+07  7.622000e+07 -1.132000e+07           NaN
# 1  8.510100e+09  1.140720e+10  1.652204e+10  1.624948e+10  1.641143e+10
#
#            2006          2007          2008          2009          2010  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1  1.845283e+10  2.048603e+10  2.367998e+10  2.514313e+10  2.497745e+10
#
#            2011          2012          2013          2014          2015  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1  2.853379e+10  2.622688e+10  2.920757e+10  2.590026e+10  2.549711e+10
#
#            2016          2017          2018          2019  2020  2021  \
# 0           NaN           NaN           NaN           NaN   NaN   NaN
# 1  2.506915e+10  2.788161e+10  2.752549e+10  3.020291e+10   NaN   NaN
#
#                       region  incomegroup  \
# 0  Latin America & Caribbean  High income
# 1                        NaN          NaN
#
#                                         specialnotes  \
# 0                                                NaN
# 1  26 countries, stretching from the Red Sea in t...
#
#                      tablename
# 0                        Aruba
# 1  Africa Eastern and Southern

# %%
cntry_code_dtl
# Out:
#     country_code                      region          incomegroup  \
# 0            ABW   Latin America & Caribbean          High income
# 1            AFE                         NaN                  NaN
# 2            AFG                  South Asia           Low income
# 3            AFW                         NaN                  NaN
# 4            AGO          Sub-Saharan Africa  Lower middle income
# ..           ...                         ...                  ...
# 260          XKX       Europe & Central Asia  Upper middle income
# 261          YEM  Middle East & North Africa           Low income
# 262          ZAF          Sub-Saharan Africa  Upper middle income
# 263          ZMB          Sub-Saharan Africa           Low income
# 264          ZWE          Sub-Saharan Africa  Lower middle income
#
#                                           specialnotes  \
# 0                                                  NaN
# 1    26 countries, stretching from the Red Sea in t...
# 2    The reporting period for national accounts dat...
# 3    22 countries, stretching from the westernmost ...
# 4    The World Bank systematically assesses the app...
# ..                                                 ...
# 260                                                NaN
# 261  The World Bank systematically assesses the app...
# 262  Fiscal year end: March 31; reporting period fo...
# 263  National accounts data were rebased to reflect...
# 264  National Accounts data are reported in Zimbabw...
#
#                        tablename
# 0                          Aruba
# 1    Africa Eastern and Southern
# 2                    Afghanistan
# 3     Africa Western and Central
# 4                         Angola
# ..                           ...
# 260                       Kosovo
# 261                  Yemen, Rep.
# 262                 South Africa
# 263                       Zambia
# 264                     Zimbabwe
#
# [265 rows x 5 columns]

# %%
aid_df.region.value_counts()
# Out:
# Europe & Central Asia         58
# Sub-Saharan Africa            48
# Latin America & Caribbean     42
# East Asia & Pacific           37
# Middle East & North Africa    21
# South Asia                     8
# North America                  3
# Name: region, dtype: int64

# %%
ID_VARS = ['country_name', 'country_code', 'indicator_name', 'indicator_code',
       'region', 'incomegroup', 'specialnotes', 'tablename']

# %%
aid_with_codes_df = aid_df.melt(id_vars=ID_VARS, 
        var_name="Year", 
        value_name="Value")

# %%
povrty_with_codes_df = povrty_df.melt(id_vars=ID_VARS, 
              var_name = "Year", 
              value_name = "Value")

# %%
inflation_with_codes_df = inflation_df.melt(id_vars=ID_VARS, 
              var_name = "Year", 
              value_name = "Value")

# %%
unemplmnt_with_codes_df = unemplmnt_df.melt(id_vars=ID_VARS, 
              var_name = "Year", 
              value_name = "Value")

# %% [markdown]
# # EDA

# %%
# unique regions
aid_with_codes_df['region'].unique()
# Out:
# array(['Latin America & Caribbean', nan, 'South Asia',
#        'Sub-Saharan Africa', 'Europe & Central Asia',
#        'Middle East & North Africa', 'East Asia & Pacific',
#        'North America'], dtype=object)

# %%
# countries in latin america
aid_with_codes_df[aid_with_codes_df.region.isin(['Latin America & Caribbean'])]['country_name'].unique()
# Out:
# array(['Aruba', 'Argentina', 'Antigua and Barbuda', 'Bahamas, The',
#        'Belize', 'Bolivia', 'Brazil', 'Barbados', 'Chile', 'Colombia',
#        'Costa Rica', 'Cuba', 'Curacao', 'Cayman Islands', 'Dominica',
#        'Dominican Republic', 'Ecuador', 'Grenada', 'Guatemala', 'Guyana',
#        'Honduras', 'Haiti', 'Jamaica', 'St. Kitts and Nevis', 'St. Lucia',
#        'St. Martin (French part)', 'Mexico', 'Nicaragua', 'Panama',
#        'Peru', 'Puerto Rico', 'Paraguay', 'El Salvador', 'Suriname',
#        'Sint Maarten (Dutch part)', 'Turks and Caicos Islands',
#        'Trinidad and Tobago', 'Uruguay', 'St. Vincent and the Grenadines',
#        'Venezuela, RB', 'British Virgin Islands', 'Virgin Islands (U.S.)'],
#       dtype=object)

# %%
# countries in latin america
aid_with_codes_df[aid_with_codes_df.region.isin(['East Asia & Pacific'])]['country_name'].unique()
# Out:
# array(['American Samoa', 'Australia', 'Brunei Darussalam', 'China',
#        'Fiji', 'Micronesia, Fed. Sts.', 'Guam', 'Hong Kong SAR, China',
#        'Indonesia', 'Japan', 'Cambodia', 'Kiribati', 'Korea, Rep.',
#        'Lao PDR', 'Macao SAR, China', 'Marshall Islands', 'Myanmar',
#        'Mongolia', 'Northern Mariana Islands', 'Malaysia',
#        'New Caledonia', 'Nauru', 'New Zealand', 'Philippines', 'Palau',
#        'Papua New Guinea', "Korea, Dem. People's Rep.",
#        'French Polynesia', 'Singapore', 'Solomon Islands', 'Thailand',
#        'Timor-Leste', 'Tonga', 'Tuvalu', 'Vietnam', 'Vanuatu', 'Samoa'],
#       dtype=object)

# %% [markdown]
# Manual filtering on countries is required.

# %% [markdown]
# ## Latin America

# %%
def plottingTimeSeries(df, filter_criteria=None, region = "Latin America & Caribbean"):
    """
        Function to plot time series data
        args:
            df : dataframe
            filter_criteria : dataframe filter in format of pd.query (default, None)
            region : filter for region (default, Latin america & Caribbean)
        
        return:
            plot : time series plot
    """
    
    ax = sns.lineplot(x = "Year", 
                       y = "Value",
                       data = df.query(filter_criteria).groupby("Year")\
                               .agg({'Value':np.nanmean}).reset_index()
                        )
    return ax

# %% [markdown]
# ### Poverty

# %%
plt.figure(figsize=(15, 6))
plottingTimeSeries(povrty_with_codes_df, filter_criteria="region == 'Latin America & Caribbean'")
plt.xticks(rotation=45)
plt.ylabel("Poverty headcount ratio@ $2.15/day")
plt.grid(linestyle='-.', linewidth=1)
plt.title("Average Poverty ratio of Latin America")
plt.show()

# %% [markdown]
# ## Foreign aid (total)

# %%
aid_with_codes_df['indicator_name'].unique()
# Out:
# array(['Net official development assistance and official aid received (current US$)'],
#       dtype=object)

# %%
plt.figure(figsize=(15, 6))
plottingTimeSeries(aid_with_codes_df, filter_criteria="region == 'Latin America & Caribbean'")
plt.xticks(rotation=45)
plt.ylabel("Official aid received (current US$)")
plt.grid(linestyle='-.', linewidth=1)
plt.title("Average Aid received by Latin America in US$")
plt.show()

# %% [markdown]
# ## Unemployment rate

# %%
unemplmnt_with_codes_df.head(2)
# Out:
#                   country_name country_code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
#
#                                       indicator_name  indicator_code  \
# 0  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS
# 1  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS
#
#                       region  incomegroup  \
# 0  Latin America & Caribbean  High income
# 1                        NaN          NaN
#
#                                         specialnotes  \
# 0                                                NaN
# 1  26 countries, stretching from the Red Sea in t...
#
#                      tablename  Year  Value
# 0                        Aruba  1960    NaN
# 1  Africa Eastern and Southern  1960    NaN

# %%
plt.figure(figsize=(15, 6))
plottingTimeSeries(unemplmnt_with_codes_df, filter_criteria="region == 'Latin America & Caribbean'")
plt.xticks(rotation=45)
plt.ylabel("Unemployment, total (% of total labor force)")
plt.grid(linestyle='-.', linewidth=1)
plt.title("Average Unemployment rate in Latin America")
plt.show()

# %% [markdown]
# ## Aid impact towards unemployment rate

# %%
f, axarr = plt.subplots(2, figsize=(16,8), sharex=True)
sns.lineplot(x = "Year", 
                       y = "Value",
                       data = povrty_with_codes_df.query("region == 'Latin America & Caribbean'")\
                               .groupby("Year")\
                               .agg({'Value':np.nanmean}).reset_index(),ax=axarr[1], color = "r")
axarr[1].set_ylabel('Poverty headcount ratio@ $2.15/day')
axarr[1].grid(linestyle="-.", linewidth=1)

sns.lineplot(x = "Year", 
                       y = "Value",
                       data = aid_with_codes_df.query("region == 'Latin America & Caribbean'")\
                               .groupby("Year")\
                               .agg({'Value':np.nanmean}).reset_index(),ax=axarr[0])
axarr[0].set_ylabel("Average Aid received by Latin America in US$")
axarr[1].tick_params(axis='x', rotation=90)
axarr[0].grid(linestyle="-.", linewidth=1)


plt.show()

# %% [markdown]
# Poverty rate started dropping after 2001. The average US aid also increased after during the same period.
#
# Could this possibly mean that US Aid towards Latin America had a significant impact on reducing the Poverty rate?

# %% [markdown]
# Lets try by breaking down the US Aid into different sectors, given to Latin America during the same period.

# %% [markdown]
# # US Aid Complete Dataset

# %%
with open("../data/latin_america_southeast_asia_usaid_complete.pickle", "rb") as file_:
    raw_us_aid = pickle.load(file_)

# %%
raw_us_aid.head(2)
# Out:
#    country_id country_code country_name  region_id         region_name  \
# 0          32          ARG    Argentina          6  Western Hemisphere
# 1          32          ARG    Argentina          6  Western Hemisphere
#
#    income_group_id            income_group_name income_group_acronym  \
# 0              3.0  Upper Middle Income Country                 UMIC
# 1              3.0  Upper Middle Income Country                 UMIC
#
#    managing_agency_id managing_agency_acronym  \
# 0                   1                   USAID
# 1                   1                   USAID
#
#                         managing_agency_name  \
# 0  U.S. Agency for International Development
# 1  U.S. Agency for International Development
#
#    managing_sub-agency_or_bureau_id managing_sub-agency_or_bureau_acronym  \
# 0                                23                                    EE
# 1                                23                                    EE
#
#   managing_sub-agency_or_bureau_name  implementing_partner_category_id  \
# 0      Bureau for Europe and Eurasia                                 1
# 1      Bureau for Europe and Eurasia                                 1
#
#   implementing_partner_category_name  implementing_partner_sub-category_id  \
# 0                         Government                                     1
# 1                         Government                                     1
#
#   implementing_partner_sub-category_name  implementing_partner_id  \
# 0             Government - United States                  1000001
# 1             Government - United States                  1000001
#
#                            implementing_partner_name  \
# 0  U.S. Government - U.S. Agency for Internationa...
# 1  U.S. Government - U.S. Agency for Internationa...
#
#    international_category_id international_category_name  \
# 0                         10        Administrative Costs
# 1                         10        Administrative Costs
#
#    international_sector_code international_sector_name  \
# 0                        911        Operating Expenses
# 1                        911        Operating Expenses
#
#    international_purpose_code international_purpose_name  us_category_id  \
# 0                       91010         Operating Expenses               8
# 1                       91010         Operating Expenses               8
#
#   us_category_name  us_sector_id               us_sector_name  \
# 0  Program Support            41  Direct Administrative Costs
# 1  Program Support            41  Direct Administrative Costs
#
#   funding_account_id                               funding_account_name  \
# 0            72x1000  Agency for International Development, Operatin...
# 1            72x1000  Agency for International Development, Operatin...
#
#    funding_agency_id                        funding_agency_name  \
# 0                  1  U.S. Agency for International Development
# 1                  1  U.S. Agency for International Development
#
#   funding_agency_acronym  foreign_assistance_objective_id  \
# 0                  USAID                                1
# 1                  USAID                                1
#
#   foreign_assistance_objective_name  aid_type_group_id   aid_type_group_name  \
# 0                          Economic                  6  Administrative Costs
# 1                          Economic                  6  Administrative Costs
#
#    aid_type_id                                aid_type_name  activity_id  \
# 0           17  Administrative costs not included elsewhere       121438
# 1           17  Administrative costs not included elsewhere       121438
#
#    submission_id     activity_name activity_description  \
# 0             76  OE TRUSFUNDS COR       OE Trust Funds
# 1             76  OE TRUSFUNDS COR       OE Trust Funds
#
#   activity_project_number activity_budget_amount activity_start_date  \
# 0                      OE                    NaN                 NaN
# 1                      OE                    NaN                 NaN
#
#   activity_end_date  transaction_type_id transaction_type_name fiscal_year  \
# 0               NaN                    2           Obligations        2001
# 1               NaN                    3         Disbursements        2001
#
#   transaction_date  current_dollar_amount  constant_dollar_amount  \
# 0              NaN                   3145                    4485
# 1              NaN                   1147                    1636
#
#    submission_activity_id  finance_type  dac_flow_id Year    region_extd
# 0                    7767           110            1       Latin America
# 1                    7767           110            1       Latin America

# %%
raw_us_aid['aid_type_group_name'].value_counts()
# Out:
# Project-Type            358619
# Administrative Costs    207369
# Technical Assistance     71730
# Core contributions        2090
# Other                       10
# Budget support               2
# Name: aid_type_group_name, dtype: int64

# %%
raw_us_aid['international_category_name'].value_counts()
# Out:
# Administrative Costs     207738
# Governance               169340
# Health and Population     87452
# Other                     54105
# Humanitarian              32061
# Education                 25062
# Agriculture               23788
# Commodity Assistance      17261
# Economic Growth           17096
# Infrastructure             5917
# Name: international_category_name, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.countplot(y = "managing_agency_name", data = raw_us_aid)
plt.grid(linestyle = "-.", linewidth=1)
plt.title("Number of Times US Aid was gi")
# Out:
# Text(0.5, 1.0, 'Number of Times US Aid was gi')

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x = "transaction_type_name", data = raw_us_aid)
# Out:
# <AxesSubplot:xlabel='transaction_type_name', ylabel='count'>

# %%
raw_us_aid.country_name.unique()
# Out:
# array(['Argentina', 'Bolivia', 'Brazil', 'Brunei', 'Burma (Myanmar)',
#        'Cambodia', 'Chile', 'Colombia', 'Costa Rica', 'Cuba',
#        'Dominican Republic', 'Ecuador', 'El Salvador', 'French Guiana',
#        'Guatemala', 'Haiti', 'Honduras', 'Indonesia', 'Laos', 'Malaysia',
#        'Martinique', 'Mexico', 'Nicaragua', 'Panama', 'Paraguay', 'Peru',
#        'Philippines', 'Timor-Leste', 'Singapore', 'Vietnam', 'Thailand',
#        'Uruguay', 'Venezuela'], dtype=object)

# %% [markdown]
# ## filter on Year (latest data)

# %%
raw_us_aid['fiscal_year'] = np.where(raw_us_aid.fiscal_year=="1976tq", "1976", raw_us_aid.fiscal_year)

# %%
raw_us_aid['fiscal_year'] = raw_us_aid['fiscal_year'].astype(int)

# %%
raw_us_aid.fiscal_year.min(), raw_us_aid.fiscal_year.max()
# Out:
# (1946, 2023)

# %%
# aid in millions
raw_us_aid['amount_in_mil'] = (raw_us_aid['constant_dollar_amount'].astype(float)/1000000).round(2)

# %%
latest_us_aid = raw_us_aid.query("fiscal_year == 2022")

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x = "region_extd", data = raw_us_aid, hue = "transaction_type_name")
# plt.title()
# Out:
# <AxesSubplot:xlabel='region_extd', ylabel='count'>

# %%
plt.figure(figsize=(15, 15))
sns.countplot(y = "country_name", 
             data = latest_us_aid, 
             hue="transaction_type_name", 
             order = latest_us_aid['country_name'].value_counts().index)
plt.ylabel("Country Name")
plt.xlabel("Count")
plt.title("Number of times US Aid given by Countries and Type")
plt.grid(linestyle = "-.", linewidth=1)

# %%
latest_us_aid.head(2)
# Out:
#     country_id country_code country_name  region_id         region_name  \
# 88          32          ARG    Argentina          6  Western Hemisphere
# 91          32          ARG    Argentina          6  Western Hemisphere
#
#     income_group_id            income_group_name income_group_acronym  \
# 88              3.0  Upper Middle Income Country                 UMIC
# 91              3.0  Upper Middle Income Country                 UMIC
#
#     managing_agency_id managing_agency_acronym managing_agency_name  \
# 88                   2                   STATE  Department of State
# 91                   2                   STATE  Department of State
#
#     managing_sub-agency_or_bureau_id managing_sub-agency_or_bureau_acronym  \
# 88                                62                                   INL
# 91                                62                                   INL
#
#                    managing_sub-agency_or_bureau_name  \
# 88  International Narcotics and Law Enforcement Af...
# 91  International Narcotics and Law Enforcement Af...
#
#     implementing_partner_category_id implementing_partner_category_name  \
# 88                                 1                         Government
# 91                                 1                         Government
#
#     implementing_partner_sub-category_id  \
# 88                                     1
# 91                                     1
#
#    implementing_partner_sub-category_name  implementing_partner_id  \
# 88             Government - United States                  1000004
# 91             Government - United States                  1000010
#
#                   implementing_partner_name  international_category_id  \
# 88    U.S. Government - Department of State                         10
# 91  U.S. Government - Department of Justice                          3
#
#    international_category_name  international_sector_code  \
# 88        Administrative Costs                        911
# 91                  Governance                        152
#
#         international_sector_name  international_purpose_code  \
# 88             Operating Expenses                       91010
# 91  Conflict, Peace, and Security                       15210
#
#                international_purpose_name  us_category_id    us_category_name  \
# 88                     Operating Expenses               8     Program Support
# 91  Security system management and reform               1  Peace and Security
#
#     us_sector_id                us_sector_name funding_account_id  \
# 88            41   Direct Administrative Costs            11x1022
# 91            45  Peace and Security - General            11x1022
#
#                                  funding_account_name  funding_agency_id  \
# 88  International Narcotics Control and Law Enforc...                  2
# 91  International Narcotics Control and Law Enforc...                  2
#
#     funding_agency_name funding_agency_acronym  \
# 88  Department of State                  STATE
# 91  Department of State                  STATE
#
#     foreign_assistance_objective_id foreign_assistance_objective_name  \
# 88                                1                          Economic
# 91                                1                          Economic
#
#     aid_type_group_id   aid_type_group_name  aid_type_id  \
# 88                  6  Administrative Costs           17
# 91                  3          Project-Type            8
#
#                                         aid_type_name  activity_id  \
# 88        Administrative costs not included elsewhere       312738
# 91  Project-type interventions - not Investment Re...       312483
#
#     submission_id                                      activity_name  \
# 88            105  Bureau of International Narcotics and Law Enfo...
# 91            105  Bureau of International Narcotics and Law Enfo...
#
#                                  activity_description activity_project_number  \
# 88  U.S. Department of State: Bureau of Internatio...             20730110299
# 91  U.S. Department of State: Bureau of Internatio...               102507301
#
#    activity_budget_amount activity_start_date activity_end_date  \
# 88                    NaN                 NaN        2021-10-07
# 91                    NaN                 NaN        2021-10-01
#
#     transaction_type_id transaction_type_name  fiscal_year transaction_date  \
# 88                    3         Disbursements         2022        07OCT2021
# 91                    2           Obligations         2022        01OCT2021
#
#     current_dollar_amount  constant_dollar_amount  submission_activity_id  \
# 88                   6430                    6209                  101320
# 91                 -12572                  -12139                  101065
#
#     finance_type  dac_flow_id Year    region_extd  amount_in_mil
# 88           110            1       Latin America           0.01
# 91           110            1       Latin America          -0.01

# %%
# there are outliers in data (constant_dollar_amount in negative)
# lets remove everything after 12 percentile

latest_us_aid = latest_us_aid[latest_us_aid.constant_dollar_amount >= latest_us_aid.constant_dollar_amount.quantile(.125)]

# %%
# aid in millions
latest_us_aid['amount_in_mil'] = (latest_us_aid['constant_dollar_amount'].astype(float)/1000000).round(2)

# %%
plot_df = latest_us_aid.groupby(["region_extd", "country_name" ,'transaction_type_name'])\
                        .agg({"amount_in_mil":np.nanmean}).reset_index()

# %%
plt.figure(figsize=(15, 8))
sns.barplot(x = "region_extd", 
            y = "amount_in_mil",
            data = plot_df, hue = "transaction_type_name")
plt.grid()
plt.ylabel("Amount (in mil)")
plt.xlabel("Region")
plt.title("Average Aid given by Region and Transaction Type - 2022", fontsize=25)
# Out:
# Text(0.5, 1.0, 'Average Aid given by Region and Transaction Type - 2022')

# %%
plt.figure(figsize=(15, 15))
sns.barplot(x = "amount_in_mil", 
                       y = "country_name",
                       data = plot_df[plot_df.region_extd=="Latin America"],
            hue = "transaction_type_name")
plt.ylabel('Countries in Latin America')
plt.xlabel('Average Aid (in mil)')
plt.grid()
plt.legend(loc=1, prop={'size': 15}, title = "Transaction Type")
plt.title("Average Aid given in Latin America by Transaction Type - 2022", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Average Aid given in Latin America by Transaction Type - 2022')

# %%
plt.figure(figsize=(15, 15))
sns.barplot(x = "amount_in_mil", 
                       y = "country_name",
                       data = plot_df[plot_df.region_extd=="South East Asia"],
            hue = "transaction_type_name")
plt.ylabel('Countries in South-East Asia')
plt.xlabel('Average Aid (in mil)')
plt.grid()
plt.legend(loc="best", prop={'size': 10}, title="Transaction Type")
plt.title("Average Aid given in South-East Asia by Transaction Type - 2022", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Average Aid given in South-East Asia by Transaction Type - 2022')

# %% [markdown]
# ## Disbursement across account type

# %%
latest_us_aid.head(2)
# Out:
#      country_id country_code country_name  region_id         region_name  \
# 88           32          ARG    Argentina          6  Western Hemisphere
# 101          32          ARG    Argentina          6  Western Hemisphere
#
#      income_group_id            income_group_name income_group_acronym  \
# 88               3.0  Upper Middle Income Country                 UMIC
# 101              3.0  Upper Middle Income Country                 UMIC
#
#      managing_agency_id managing_agency_acronym managing_agency_name  \
# 88                    2                   STATE  Department of State
# 101                   2                   STATE  Department of State
#
#      managing_sub-agency_or_bureau_id managing_sub-agency_or_bureau_acronym  \
# 88                                 62                                   INL
# 101                                62                                   INL
#
#                     managing_sub-agency_or_bureau_name  \
# 88   International Narcotics and Law Enforcement Af...
# 101  International Narcotics and Law Enforcement Af...
#
#      implementing_partner_category_id implementing_partner_category_name  \
# 88                                  1                         Government
# 101                                 8                        Enterprises
#
#      implementing_partner_sub-category_id  \
# 88                                      1
# 101                                    19
#
#     implementing_partner_sub-category_name  implementing_partner_id  \
# 88              Government - United States                  1000004
# 101            Enterprises - United States                  3990208
#
#                  implementing_partner_name  international_category_id  \
# 88   U.S. Government - Department of State                         10
# 101    Enterprise - United States Redacted                          3
#
#     international_category_name  international_sector_code  \
# 88         Administrative Costs                        911
# 101                  Governance                        151
#
#         international_sector_name  international_purpose_code  \
# 88             Operating Expenses                       91010
# 101  Government and Civil Society                       15130
#
#          international_purpose_name  us_category_id  \
# 88               Operating Expenses               8
# 101  Legal and judicial development               2
#
#                             us_category_name  us_sector_id  \
# 88                           Program Support            41
# 101  Democracy, Human Rights, and Governance             7
#
#                    us_sector_name funding_account_id  \
# 88    Direct Administrative Costs            11x1022
# 101  Rule of Law and Human Rights            11x1022
#
#                                   funding_account_name  funding_agency_id  \
# 88   International Narcotics Control and Law Enforc...                  2
# 101  International Narcotics Control and Law Enforc...                  2
#
#      funding_agency_name funding_agency_acronym  \
# 88   Department of State                  STATE
# 101  Department of State                  STATE
#
#      foreign_assistance_objective_id foreign_assistance_objective_name  \
# 88                                 1                          Economic
# 101                                1                          Economic
#
#      aid_type_group_id   aid_type_group_name  aid_type_id  \
# 88                   6  Administrative Costs           17
# 101                  3          Project-Type            8
#
#                                          aid_type_name  activity_id  \
# 88         Administrative costs not included elsewhere       312738
# 101  Project-type interventions - not Investment Re...       318543
#
#      submission_id                                      activity_name  \
# 88             105  Bureau of International Narcotics and Law Enfo...
# 101            105  Bureau of International Narcotics and Law Enfo...
#
#                                   activity_description  \
# 88   U.S. Department of State: Bureau of Internatio...
# 101  U.S. Department of State: Bureau of Internatio...
#
#     activity_project_number activity_budget_amount activity_start_date  \
# 88              20730110299                    NaN                 NaN
# 101           19AR2021K0252                    NaN                 NaN
#
#     activity_end_date  transaction_type_id transaction_type_name  fiscal_year  \
# 88         2021-10-07                    3         Disbursements         2022
# 101        2021-10-25                    3         Disbursements         2022
#
#     transaction_date  current_dollar_amount  constant_dollar_amount  \
# 88         07OCT2021                   6430                    6209
# 101        25OCT2021                    286                     276
#
#      submission_activity_id  finance_type  dac_flow_id Year    region_extd  \
# 88                   101320           110            1       Latin America
# 101                  107125           110            1       Latin America
#
#      amount_in_mil
# 88            0.01
# 101           0.00

# %%
plot_df = raw_us_aid.groupby(['us_category_name', 'fiscal_year','region_extd'])\
                .agg({'amount_in_mil':np.nanmean}).reset_index()

# %%
plot_df.head()
# Out:
#                           us_category_name  fiscal_year      region_extd  \
# 0  Democracy, Human Rights, and Governance         1988    Latin America
# 1  Democracy, Human Rights, and Governance         1988  South East Asia
# 2  Democracy, Human Rights, and Governance         1989    Latin America
# 3  Democracy, Human Rights, and Governance         1989  South East Asia
# 4  Democracy, Human Rights, and Governance         1990    Latin America
#
#    amount_in_mil
# 0       6.543125
# 1       4.387500
# 2       5.949375
# 3       2.092500
# 4       2.147000

# %%
plt.figure(figsize=(20, 10))
sns.lineplot(y = "amount_in_mil", 
            x = "fiscal_year",
             data = plot_df[(plot_df.region_extd=='Latin America') & (plot_df.fiscal_year>2000)], 
            hue = "us_category_name")
plt.xlabel("Fiscal Year")
plt.ylabel("Amount (in mil)")
plt.legend(loc="best", prop={'size': 15}, title="Category Type")
plt.title("Average US Aid to Latin America by Category : 2001 - 2022", fontsize=25)
# Out:
# Text(0.5, 1.0, 'Average US Aid to Latin America by Category : 2001 - 2022')
